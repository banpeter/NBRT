# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import math

# %%
dataset_names = ["Blob","iris","wine","house_price"]
#rt - regression tree
#rtl - regression tree linear regresion
#rtln - regression tree linear regresion non binray
#rtn - regression tree non binray
#rtni - regression tree linear regresion non binray incremental
#The meaning of the numbers next to the non binary trees, is the amount of sub_nodes

# %%
#Execution time
times = []

with open("Results/times_rt2.csv","r") as file:
    t = []
    tmp = []
    for row in file:
        t.append(float(row.strip("\n")))
    for i in range(4):
        print(len(t))
        tmp.append((t[i]+t[i+4]+t[i+8]+t[i+12]+t[i+16])/5)
    times.append(tmp)
    #print(times)

   
    
with open("Results/times_rtl.csv","r") as file:
    t = []
    tmp = []
    for row in file:
        t.append(float(row.strip("\n")))
    for i in range(4):
        #print(len(t))
        tmp.append((t[i]+t[i+4]+t[i+8]+t[i+12]+t[i+16])/5)
    times.append(tmp)
    #print(times)
 
'''with open("Results/times_rtln.csv","r") as file:
    t = []
    tmp = []
    temp = []
    for row in file:
        #print(row)
        row = row.strip('\n').split(',')
        #print(row)
        t.append([float(x) for x in row ])

    for i in range(4):
        print(t[i])
        tmp = []
        for j in range(4):
            tmp.append( (t[i][j]+t[i+4][j]+t[i+8][j]+t[i+12][j]+t[i+16][j])/5   )
        temp.append(tmp)
    print(temp)
    #print(t)
    times.append(temp)'''


with open("Results/times_rtn2.csv","r") as file:
    t = []
    tmp = []
    temp = []
    for row in file:
        #print(row)
        row = row.strip('\n').split(',')
        #print(row)
        t.append([float(x) for x in row ])

    for i in range(4):
        print(t[i])
        tmp = []
        for j in range(4):
            tmp.append( (t[i][j]+t[i+4][j]+t[i+8][j]+t[i+12][j]+t[i+16][j])/5   )
        temp.append(tmp)
    print(temp)
    #print(t)
    times.append(temp)

   
    
with open("Results/times_rtn.csv","r") as file:
    t = []
    tmp = []
    temp = []
    for row in file:
        #print(row)
        row = row.strip('\n').split(',')
        #print(row)
        t.append([float(x) for x in row ])

    for i in range(4):
        print(t[i])
        tmp = []
        for j in range(4):
            tmp.append( (t[i][j]+t[i+4][j]+t[i+8][j]+t[i+12][j]+t[i+16][j])/5   )
        temp.append(tmp)
    print(temp)
    #print(t)
    times.append(temp)
            
    

    
'''with open("DataSets/times_rtni.csv","r") as file:
    t = []
    
    for row in file:
        #print(row)
        row = row.strip('\n').split(',')
        #print(row)
        t.append([float(x) for x in row ])
    
    times.append(t)'''
# Out:
# 20
# 20
# 20
# 20
# [1.2421371936798096, 0.7985062599182129, 0.6228373050689697, 0.5992441177368164]
# [0.012469291687011719, 0.00696873664855957, 0.0049974918365478516, 0.005010128021240234]
# [22.887861013412476, 8.715181350708008, 5.739150524139404, 4.039023160934448]
# [3.5801126956939697, 2.38496994972229, 1.9067046642303467, 1.53755784034729]
# [[1.2685970306396483, 0.7956844806671143, 0.6343700885772705, 0.5988919734954834], [0.011243200302124024, 0.006907749176025391, 0.005276632308959961, 0.004876279830932617], [19.534340333938598, 8.505093431472778, 4.98660798072815, 3.820084238052368], [3.591054391860962, 2.4092106342315676, 1.8854711532592774, 1.5723042488098145]]
# [2.62674617767334, 2.0807418823242188, 1.7684993743896484, 1.434497356414795]
# [0.025728940963745117, 0.014586687088012695, 0.013079643249511719, 0.012670755386352539]
# [44.58220100402832, 19.266377210617065, 14.845545530319214, 10.31575083732605]
# ...

# %%
#Sum of difference between the test and predicted data
diff = []
with open("Results/difference_rt2.csv","r") as file:
    d = []
    for row in file:
        #print(row)
        d.append(float(row))
    diff.append(d)    

with open("Results/difference_rtl.csv","r") as file:
    d = []
    for row in file:
        #print(row)
        d.append(float(row))  
    diff.append(d)
 

'''
with open("Results/difference_rtln.csv","r") as file:
    d = []
    tmp = []
    temp = []
    for row in file:
        row = row.strip('\n').split(',')
        #print(row)
        row = [x.strip('[]') for x in row]
        d.append([float(x) for x in row ]) 
    
    
    for i in range(4):
        tmp = []
        for j in range(4):
            tmp.append( (d[i][j]+d[i+4][j]+d[i+8][j]+d[i+12][j]+d[i+16][j])/5   )
        temp.append(tmp)
    print(temp)
    
    
    diff.append(temp)'''

with open("Results/difference_rtn2.csv","r") as file:
    d = []
    tmp = []
    temp = []
    for row in file:
        row = row.strip('\n').split(',')
        #print(row)
        row = [x.strip('[]') for x in row]
        d.append([float(x) for x in row ]) 
    
    
    for i in range(4):
        tmp = []
        for j in range(4):
            tmp.append( (d[i][j]+d[i+4][j]+d[i+8][j]+d[i+12][j]+d[i+16][j])/5   )
        temp.append(tmp)
    print(temp)
    
    
    diff.append(temp)



with open("Results/difference_rtn.csv","r") as file:
    d = []
    tmp = []
    temp = []
    for row in file:
        row = row.strip('\n').split(',')
        #print(row)
        d.append([float(x) for x in row ]) 
    
    
    for i in range(4):
        tmp = []
        for j in range(4):
            tmp.append( (d[i][j]+d[i+4][j]+d[i+8][j]+d[i+12][j]+d[i+16][j])/5   )
        temp.append(tmp)
    print(temp)
    
    
    diff.append(temp)

   
    
    
    
'''with open("DataSets/difference_rtni.csv","r") as file:
    d = []
    for row in file:
        row = row.strip('\n').split(',')
        #print(row)
        d.append([float(x) for x in row ])   
    diff.append(d)'''
print(len(diff))
# Out:
# [[0.07488812434504584, 0.06527425751668434, 0.08618601467320897, 0.0862832998812267], [0.03686591815838387, 0.025157416764429417, 0.03229654237511999, 0.05248240740740741], [0.5648202627140348, 0.5949706734810121, 0.601427391954058, 0.6188839398737358], [14.96820280381048, 17.428193389007582, 17.454808417949412, 20.20963265079047]]
# [[0.07360534521391206, 0.10789443347992433, 0.08600095568151685, 0.08979333783261664], [0.05824898672804703, 0.03328247025615872, 0.05531215031969461, 0.06100110455246914], [0.5770089422972189, 0.5850536114753269, 0.5994843608348092, 0.6037423017999386], [19.747326073762313, 21.008554893526043, 17.96432654491594, 17.601996947132694]]
# 4

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [diff[0][0],diff[1][0]]


for i in diff[2:]:
    for j in i[0]:
        data.append(j)

#color=['black', 'red', 'green', 'blue', 'cyan','black', 'red', 'green', 'blue', 'cyan','blue', 'cyan','blue', 'cyan']
#print(house_data)
#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('clob_error2.png') 
#plt.legend(["Testing data" , "Predicted value"])

plt.xlabel("Dataset")
plt.ylabel("Error")
plt.title("Blob")

plt.show()

# %%
data = [times[0][0],times[1][0]]


for i in times[2:]:

    for j in i[0]:
        data.append(j)


#print(house_data)
#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('clob_time2.png') 


plt.xlabel("Dataset")
plt.ylabel("Time(s)")
plt.title("Blob")

plt.show()

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [diff[0][1],diff[1][1]]


for i in diff[2:]:
    for j in i[1]:
        data.append(j)


print(data)
#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('iris_error2.png') 
#plt.legend(["Testing data" , "Predicted value"])

plt.xlabel("Dataset")
plt.ylabel("Error")
plt.title("Iris")

plt.show()
# Out:
# [0.06721913805697598, 0.05664658947364709, 0.03686591815838387, 0.025157416764429417, 0.03229654237511999, 0.05248240740740741, 0.05824898672804703, 0.03328247025615872, 0.05531215031969461, 0.06100110455246914]

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [times[0][1],times[1][1]]


for i in times[2:]:

    for j in i[1]:
        data.append(j)


#print(house_data)
#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('iris_time2.png') 


plt.xlabel("Dataset")
plt.ylabel("Time(s)")
plt.title("Iris")

plt.show()

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [diff[0][2],diff[1][2]]


for i in diff[2:]:
    for j in i[2]:
        data.append(j)


#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('wine_error2.png') 
#plt.legend(["Testing data" , "Predicted value"])

plt.xlabel("Dataset")
plt.ylabel("Error")
plt.title("Wine")

plt.show()

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [times[0][2],times[1][2]]


for i in times[2:]:

    for j in i[2]:
        data.append(j)


#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('wine_time2.png') 


plt.xlabel("Dataset")
plt.ylabel("Time(s)")
plt.title("Wine")

plt.show()

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [diff[0][3],diff[1][3]]


for i in diff[2:]:
    for j in i[3]:
        data.append(j)



#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('house_error2.png') 
#plt.legend(["Testing data" , "Predicted value"])

plt.xlabel("Dataset")
plt.ylabel("Error")
plt.title("House")

plt.show()

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [times[0][3],times[1][3]]


for i in times[2:]:

    for j in i[3]:
        data.append(j)



#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('house_time2.png') 


plt.xlabel("Dataset")
plt.ylabel("Time(s)")
plt.title("House")

plt.show()
