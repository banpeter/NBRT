# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import math

# %%
dataset_names = ["Blob","iris","wine","house_price"]
#rt - regression tree
#rtl - regression tree linear regresion
#rtln - regression tree linear regresion non binray
#rtn - regression tree non binray
#rtni - regression tree linear regresion non binray incremental
#The meaning of the numbers next to the non binary trees, is the amount of sub_nodes

# %%
#Execution time
times = []

with open("Results3/times_rt.csv","r") as file:
    t = []
    tmp = []
    for row in file:
        t.append(float(row.strip("\n")))
    for i in range(4):
        print(len(t))
        tmp.append((t[i]+t[i+4]+t[i+8]+t[i+12]+t[i+16])/5)
    times.append(tmp)
    #print(times)

   
    
with open("Results3/times_rtl.csv","r") as file:
    t = []
    tmp = []
    for row in file:
        t.append(float(row.strip("\n")))
    for i in range(4):
        #print(len(t))
        tmp.append((t[i]+t[i+4]+t[i+8]+t[i+12]+t[i+16])/5)
    times.append(tmp)
    #print(times)
 
'''with open("Results/times_rtln.csv","r") as file:
    t = []
    tmp = []
    temp = []
    for row in file:
        #print(row)
        row = row.strip('\n').split(',')
        #print(row)
        t.append([float(x) for x in row ])

    for i in range(4):
        print(t[i])
        tmp = []
        for j in range(4):
            tmp.append( (t[i][j]+t[i+4][j]+t[i+8][j]+t[i+12][j]+t[i+16][j])/5   )
        temp.append(tmp)
    print(temp)
    #print(t)
    times.append(temp)'''


with open("Results3/times_rtn.csv","r") as file:
    t = []
    tmp = []
    temp = []
    for row in file:
        #print(row)
        row = row.strip('\n').split(',')
        #print(row)
        t.append([float(x) for x in row ])

    for i in range(4):
        print(t[i])
        tmp = []
        for j in range(4):
            tmp.append( (t[i][j]+t[i+4][j]+t[i+8][j]+t[i+12][j]+t[i+16][j])/5   )
        temp.append(tmp)
    print(temp)
    #print(t)
    times.append(temp)

   
    
with open("Results3/times_rtn.csv","r") as file:
    t = []
    tmp = []
    temp = []
    for row in file:
        #print(row)
        row = row.strip('\n').split(',')
        #print(row)
        t.append([float(x) for x in row ])

    for i in range(4):
        print(t[i])
        tmp = []
        for j in range(4):
            tmp.append( (t[i][j]+t[i+4][j]+t[i+8][j]+t[i+12][j]+t[i+16][j])/5   )
        temp.append(tmp)
    print(temp)
    #print(t)
    times.append(temp)
# Out:
# 20
# 20
# 20
# 20
# [17.325579404830933, 12.998695850372314, 12.44478440284729, 11.75841760635376]
# [0.0054285526275634766, 0.0041391849517822266, 0.0033795833587646484, 0.0034117698669433594]
# [30.43389868736267, 23.395824909210205, 20.715211629867554, 19.34350347518921]
# [59.30704855918884, 42.4612832069397, 38.689826011657715, 36.40081858634949]
# [[17.20796055793762, 12.878793525695801, 12.159525728225708, 11.48383388519287], [0.00595707893371582, 0.004051876068115234, 0.003400278091430664, 0.003313922882080078], [30.98559718132019, 23.06497163772583, 20.676965713500977, 19.401823568344117], [59.974954223632814, 42.83843755722046, 38.978723478317264, 36.55576777458191]]
# [17.325579404830933, 12.998695850372314, 12.44478440284729, 11.75841760635376]
# [0.0054285526275634766, 0.0041391849517822266, 0.0033795833587646484, 0.0034117698669433594]
# [30.43389868736267, 23.395824909210205, 20.715211629867554, 19.34350347518921]
# [59.30704855918884, 42.4612832069397, 38.689826011657715, 36.40081858634949]
# [[17.20796055793762, 12.878793525695801, 12.159525728225708, 11.48383388519287], [0.00595707893371582, 0.004051876068115234, 0.003400278091430664, 0.003313922882080078], [30.98559718132019, 23.06497163772583, 20.676965713500977, 19.401823568344117], [59.974954223632814, 42.83843755722046, 38.978723478317264, 36.55576777458191]]

# %%
#Sum of difference between the test and predicted data
diff = []
with open("Results/difference_rt2.csv","r") as file:
    d = []
    for row in file:
        #print(row)
        d.append(float(row))
    diff.append(d)    

with open("Results3/difference_rtl.csv","r") as file:
    d = []
    for row in file:
        #print(row)
        d.append(float(row))  
    diff.append(d)
 

'''
with open("Results/difference_rtln.csv","r") as file:
    d = []
    tmp = []
    temp = []
    for row in file:
        row = row.strip('\n').split(',')
        #print(row)
        row = [x.strip('[]') for x in row]
        d.append([float(x) for x in row ]) 
    
    
    for i in range(4):
        tmp = []
        for j in range(4):
            tmp.append( (d[i][j]+d[i+4][j]+d[i+8][j]+d[i+12][j]+d[i+16][j])/5   )
        temp.append(tmp)
    print(temp)
    
    
    diff.append(temp)'''

with open("Results3/difference_rtn.csv","r") as file:
    d = []
    tmp = []
    temp = []
    for row in file:
        row = row.strip('\n').split(',')
        #print(row)
        row = [x.strip('[]') for x in row]
        d.append([float(x) for x in row ]) 
    
    
    for i in range(4):
        tmp = []
        for j in range(4):
            tmp.append( (d[i][j]+d[i+4][j]+d[i+8][j]+d[i+12][j]+d[i+16][j])/5   )
        temp.append(tmp)
    print(temp)
    
    
    diff.append(temp)



with open("Results3/difference_rtn.csv","r") as file:
    d = []
    tmp = []
    temp = []
    for row in file:
        row = row.strip('\n').split(',')
        #print(row)
        d.append([float(x) for x in row ]) 
    
    
    for i in range(4):
        tmp = []
        for j in range(4):
            tmp.append( (d[i][j]+d[i+4][j]+d[i+8][j]+d[i+12][j]+d[i+16][j])/5   )
        temp.append(tmp)
    print(temp)
    
    
    diff.append(temp)

   
    
    
    

print(len(diff))
# Out:
# [[0.05095487936267505, 0.04544577177728509, 0.04959789073886203, 0.0746415433238153], [0.049944984255747824, 0.07539294973823712, 0.06378868387907428, 0.0684769211388259], [0.6135622697669284, 0.6340352047740653, 0.6647608615934579, 0.6420018494837368], [21.165189303935072, 18.37283506183389, 20.244716548582183, 21.47941080918764]]
# [[0.05095487936267505, 0.04544577177728509, 0.04959789073886203, 0.0746415433238153], [0.049944984255747824, 0.07539294973823712, 0.06378868387907428, 0.0684769211388259], [0.6135622697669284, 0.6340352047740653, 0.6647608615934579, 0.6420018494837368], [21.165189303935072, 18.37283506183389, 20.244716548582183, 21.47941080918764]]
# 4

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [diff[0][0],diff[1][0]]


for i in diff[2:]:
    for j in i[0]:
        data.append(j)

#color=['black', 'red', 'green', 'blue', 'cyan','black', 'red', 'green', 'blue', 'cyan','blue', 'cyan','blue', 'cyan']
#print(house_data)
#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('clob_error2.png') 
#plt.legend(["Testing data" , "Predicted value"])

plt.xlabel("Dataset")
plt.ylabel("Error")
plt.title("Blob")

plt.show()

# %%
data = [times[0][0],times[1][0]]


for i in times[2:]:

    for j in i[0]:
        data.append(j)


#print(house_data)
#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('clob_time2.png') 


plt.xlabel("Dataset")
plt.ylabel("Time(s)")
plt.title("Blob")

plt.show()

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [diff[0][1],diff[1][1]]


for i in diff[2:]:
    for j in i[1]:
        data.append(j)


print(data)
#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('iris_error2.png') 
#plt.legend(["Testing data" , "Predicted value"])

plt.xlabel("Dataset")
plt.ylabel("Error")
plt.title("Iris")

plt.show()
# Out:
# [0.06721913805697598, 0.058210213737380063, 0.049944984255747824, 0.07539294973823712, 0.06378868387907428, 0.0684769211388259, 0.049944984255747824, 0.07539294973823712, 0.06378868387907428, 0.0684769211388259]

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [times[0][1],times[1][1]]


for i in times[2:]:

    for j in i[1]:
        data.append(j)


#print(house_data)
#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('iris_time2.png') 


plt.xlabel("Dataset")
plt.ylabel("Time(s)")
plt.title("Iris")

plt.show()

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [diff[0][2],diff[1][2]]


for i in diff[2:]:
    for j in i[2]:
        data.append(j)


#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('wine_error2.png') 
#plt.legend(["Testing data" , "Predicted value"])

plt.xlabel("Dataset")
plt.ylabel("Error")
plt.title("Wine")

plt.show()

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [times[0][2],times[1][2]]


for i in times[2:]:

    for j in i[2]:
        data.append(j)


#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('wine_time2.png') 


plt.xlabel("Dataset")
plt.ylabel("Time(s)")
plt.title("Wine")

plt.show()

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [diff[0][3],diff[1][3]]


for i in diff[2:]:
    for j in i[3]:
        data.append(j)



#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('house_error2.png') 
#plt.legend(["Testing data" , "Predicted value"])

plt.xlabel("Dataset")
plt.ylabel("Error")
plt.title("House")

plt.show()

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [times[0][3],times[1][3]]


for i in times[2:]:

    for j in i[3]:
        data.append(j)



#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('house_time2.png') 


plt.xlabel("Dataset")
plt.ylabel("Time(s)")
plt.title("House")

plt.show()
