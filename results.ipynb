# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import math

# %%
dataset_names = ["Blob","iris","wine","house_price"]
#rt - regression tree
#rtl - regression tree linear regresion
#rtln - regression tree linear regresion non binray
#rtn - regression tree non binray
#rtni - regression tree linear regresion non binray incremental
#The meaning of the numbers next to the non binary trees, is the amount of sub_nodes

# %%
#Execution time
times = []

with open("Results/times_rt.csv","r") as file:
    t = []
    tmp = []
    for row in file:
        t.append(float(row.strip("\n")))
    for i in range(4):
        print(len(t))
        tmp.append((t[i]+t[i+4]+t[i+8]+t[i+12]+t[i+16])/5)
    times.append(tmp)
    #print(times)

   
    
with open("Results/times_rtl.csv","r") as file:
    t = []
    tmp = []
    for row in file:
        t.append(float(row.strip("\n")))
    for i in range(4):
        #print(len(t))
        tmp.append((t[i]+t[i+4]+t[i+8]+t[i+12]+t[i+16])/5)
    times.append(tmp)
    #print(times)
 
with open("Results/times_rtln.csv","r") as file:
    t = []
    tmp = []
    temp = []
    for row in file:
        #print(row)
        row = row.strip('\n').split(',')
        #print(row)
        t.append([float(x) for x in row ])

    for i in range(4):
        print(t[i])
        tmp = []
        for j in range(4):
            tmp.append( (t[i][j]+t[i+4][j]+t[i+8][j]+t[i+12][j]+t[i+16][j])/5   )
        temp.append(tmp)
    print(temp)
    #print(t)
    times.append(temp)

   
    
with open("Results/times_rtn.csv","r") as file:
    t = []
    tmp = []
    temp = []
    for row in file:
        #print(row)
        row = row.strip('\n').split(',')
        #print(row)
        t.append([float(x) for x in row ])

    for i in range(4):
        print(t[i])
        tmp = []
        for j in range(4):
            tmp.append( (t[i][j]+t[i+4][j]+t[i+8][j]+t[i+12][j]+t[i+16][j])/5   )
        temp.append(tmp)
    print(temp)
    #print(t)
    times.append(temp)
            
    

    
'''with open("DataSets/times_rtni.csv","r") as file:
    t = []
    
    for row in file:
        #print(row)
        row = row.strip('\n').split(',')
        #print(row)
        t.append([float(x) for x in row ])
    
    times.append(t)'''
# Out:
# 20
# 20
# 20
# 20
# [1.6857941150665283, 1.7378833293914795, 1.5863866806030273, 1.660827398300171]
# [0.3399066925048828, 0.21262073516845703, 0.2341756820678711, 0.20746684074401855]
# [8.500714540481567, 27.761138200759888, 12.119902849197388, 30.97110080718994]
# [64.88232398033142, 45.65072059631348, 32.75684213638306, 27.9770724773407]
# [[1.7782318592071533, 1.665802240371704, 1.6938821792602539, 1.6814564228057862], [0.3209439754486084, 0.19831223487854005, 0.20568594932556153, 0.17174286842346193], [10.68052372932434, 28.417556858062746, 15.857387351989747, 24.80930438041687], [65.37015109062195, 45.120841598510744, 32.94591403007507, 28.158735513687134]]
# [1.1793837547302246, 1.1553046703338623, 1.2151579856872559, 1.1135098934173584]
# [0.011052370071411133, 0.010900497436523438, 0.011032581329345703, 0.010779380798339844]
# [2.020735502243042, 2.1190123558044434, 2.0983142852783203, 2.061699390411377]
# [8.999969005584717, 7.572741746902466, 6.8184051513671875, 6.419867753982544]
# [[1.1814962863922118, 1.1571955680847168, 1.174100685119629, 1.1310495853424072], [0.011118793487548828, 0.010981273651123048, 0.011009740829467773, 0.010912179946899414], [2.0867465496063233, 2.073824977874756, 2.0682194232940674, 2.030490493774414], [9.000238847732543, 7.56693549156189, 6.865452861785888, 6.42276930809021]]
# 'with open("DataSets/times_rtni.csv","r") as file:\n    t = []\n    \n    for row in file:\n        #print(row)\n        row = row.strip(\'\n\').split(\',\')\n        #print(row)\n        t.append([float(x) for x in row ])\n    \n    times.append(t)'

# %%
#Sum of difference between the test and predicted data
diff = []
with open("Results/difference_rt.csv","r") as file:
    d = []
    for row in file:
        #print(row)
        d.append(float(row))
    diff.append(d)    

with open("Results/difference_rtl.csv","r") as file:
    d = []
    for row in file:
        #print(row)
        d.append(float(row))  
    diff.append(d)
 


with open("Results/difference_rtln.csv","r") as file:
    d = []
    tmp = []
    temp = []
    for row in file:
        row = row.strip('\n').split(',')
        #print(row)
        d.append([float(x) for x in row ]) 
    
    
    for i in range(4):
        tmp = []
        for j in range(4):
            tmp.append( (d[i][j]+d[i+4][j]+d[i+8][j]+d[i+12][j]+d[i+16][j])/5   )
        temp.append(tmp)
    print(temp)
    
    
    diff.append(temp)



with open("Results/difference_rtn.csv","r") as file:
    d = []
    tmp = []
    temp = []
    for row in file:
        row = row.strip('\n').split(',')
        #print(row)
        d.append([float(x) for x in row ]) 
    
    
    for i in range(4):
        tmp = []
        for j in range(4):
            tmp.append( (d[i][j]+d[i+4][j]+d[i+8][j]+d[i+12][j]+d[i+16][j])/5   )
        temp.append(tmp)
    print(temp)
    
    
    diff.append(temp)

   
    
    
    
'''with open("DataSets/difference_rtni.csv","r") as file:
    d = []
    for row in file:
        row = row.strip('\n').split(',')
        #print(row)
        d.append([float(x) for x in row ])   
    diff.append(d)'''
print(len(diff))
# Out:
# [[0.22958722800000003, 0.213468664, 0.21265362, 0.21244502400000004], [0.066529582, 0.082565766, 0.070192396, 0.07632413600000001], [0.6636290739999999, 0.831842516, 0.7470032379999999, 0.9089734220000001], [15.219105555999999, 17.237480566000002, 17.775108523999997, 16.760890936000003]]
# [[0.9868085566835194, 0.481954497662611, 0.3421234036774659, 0.3127070331045535], [0.18889189615618368, 0.09656134162082045, 0.1088500478112272, 0.11569754581828591], [0.7543502503525304, 0.7440160332100907, 0.7270432585587641, 0.7325767070212688], [21.39826432922134, 20.021908695661885, 19.821335324596255, 19.02194390329769]]
# 4

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [diff[0][0],diff[1][0]]


for i in diff[2:]:
    for j in i[0]:
        data.append(j)

#color=['black', 'red', 'green', 'blue', 'cyan','black', 'red', 'green', 'blue', 'cyan','blue', 'cyan','blue', 'cyan']
#print(house_data)
#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('clob_error.png') 
#plt.legend(["Testing data" , "Predicted value"])

plt.xlabel("Dataset")
plt.ylabel("Error")
plt.title("Blob")

plt.show()

# %%
plt.rcParams["figure.figsize"] = (10,15)

data = [times[0][0],times[1][0]]


for i in times[2:]:

    for j in i[0]:
        data.append(j)


#print(house_data)
#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('clob_time.png') 


plt.xlabel("Dataset")
plt.ylabel("Time(s)")
plt.title("Blob")

plt.show()

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [diff[0][1],diff[1][1]]


for i in diff[2:]:
    for j in i[1]:
        data.append(j)


print(data)
#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('iris_error.png') 
#plt.legend(["Testing data" , "Predicted value"])

plt.xlabel("Dataset")
plt.ylabel("Error")
plt.title("Iris")

plt.show()
# Out:
# [0.19191544386349593, 0.0386309843858245, 0.066529582, 0.082565766, 0.070192396, 0.07632413600000001, 0.18889189615618368, 0.09656134162082045, 0.1088500478112272, 0.11569754581828591]

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [times[0][1],times[1][1]]


for i in times[2:]:

    for j in i[1]:
        data.append(j)


#print(house_data)
#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('iris_time.png') 


plt.xlabel("Dataset")
plt.ylabel("Time(s)")
plt.title("Iris")

plt.show()

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [diff[0][2],diff[1][2]]


for i in diff[2:]:
    for j in i[2]:
        data.append(j)


#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('wine_error.png') 
#plt.legend(["Testing data" , "Predicted value"])

plt.xlabel("Dataset")
plt.ylabel("Error")
plt.title("Wine")

plt.show()

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [times[0][2],times[1][2]]


for i in times[2:]:

    for j in i[2]:
        data.append(j)


#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('wine_time.png') 


plt.xlabel("Dataset")
plt.ylabel("Time(s)")
plt.title("Wine")

plt.show()

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [diff[0][3],diff[1][3]]


for i in diff[2:]:
    for j in i[3]:
        data.append(j)



#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('house_error.png') 
#plt.legend(["Testing data" , "Predicted value"])

plt.xlabel("Dataset")
plt.ylabel("Error")
plt.title("House")

plt.show()

# %%
plt.rcParams["figure.figsize"] = (15,7)

data = [times[0][3],times[1][3]]


for i in times[2:]:

    for j in i[3]:
        data.append(j)



#plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn4","rtlni2","rtlni3","rtlni4","rtlni5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan','cyan', 'cyan','cyan','cyan'])
plt.bar(["rt","rtl","rtln2","rtln3","rtln4","rtln5","rtn2","rtn3","rtn4","rtn5"],data,color=['red', 'red', 'cyan', 'cyan', 'cyan','cyan', 'cyan', 'cyan', 'cyan', 'cyan'])
plt.savefig('house_time.png') 


plt.xlabel("Dataset")
plt.ylabel("Time(s)")
plt.title("House")

plt.show()
